# %%
"""
    A simple neural network written in Keras (TensorFlow backend) to classify the IRIS data
"""

import numpy as np

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
iris_data = load_iris() # load the iris dataset

x = iris_data.data
y_ = iris_data.target.reshape(-1, 1) # Convert data to a single column

# %%
# One Hot encode the class labels
encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y_)
#print(y)

# %%
# Split the data for training and testing
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.20)

# %%
# Build the model
model = Sequential()
model.add(Dense(10, input_shape=(4,), activation='relu', name='input'))
model.add(Dense(10, activation='relu', name='fc2'))
model.add(Dense(3, activation='softmax', name='output'))

# %%
# Adam optimizer with learning rate of 0.001
optimizer = Adam(lr=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('Neural Network Model Summary: ')
print(model.summary())
# Out:
# Neural Network Model Summary:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (Dense)               (None, 10)                50
#
#  fc2 (Dense)                 (None, 10)                110
#
#  output (Dense)              (None, 3)                 33
#
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Users\YASH\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# Train the model
model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=200)
# Out:
# Epoch 1/200
# 24/24 - 1s - loss: 2.1751 - accuracy: 0.3417 - 627ms/epoch - 26ms/step
# Epoch 2/200
# 24/24 - 0s - loss: 1.6609 - accuracy: 0.3417 - 34ms/epoch - 1ms/step
# Epoch 3/200
# 24/24 - 0s - loss: 1.3008 - accuracy: 0.4167 - 36ms/epoch - 1ms/step
# Epoch 4/200
# 24/24 - 0s - loss: 1.1041 - accuracy: 0.6833 - 21ms/epoch - 871us/step
# Epoch 5/200
# 24/24 - 0s - loss: 1.0249 - accuracy: 0.6750 - 34ms/epoch - 1ms/step
# Epoch 6/200
# 24/24 - 0s - loss: 0.9960 - accuracy: 0.8083 - 35ms/epoch - 1ms/step
# Epoch 7/200
# 24/24 - 0s - loss: 0.9649 - accuracy: 0.8250 - 34ms/epoch - 1ms/step
# Epoch 8/200
# 24/24 - 0s - loss: 0.9399 - accuracy: 0.8417 - 33ms/epoch - 1ms/step
# Epoch 9/200
# 24/24 - 0s - loss: 0.9179 - accuracy: 0.8500 - 32ms/epoch - 1ms/step
# Epoch 10/200
# 24/24 - 0s - loss: 0.9004 - accuracy: 0.8500 - 30ms/epoch - 1ms/step
# Epoch 11/200
# 24/24 - 0s - loss: 0.8806 - accuracy: 0.8167 - 38ms/epoch - 2ms/step
# Epoch 12/200
# 24/24 - 0s - loss: 0.8660 - accuracy: 0.7750 - 31ms/epoch - 1ms/step
# Epoch 13/200
# 24/24 - 0s - loss: 0.8418 - accuracy: 0.8083 - 33ms/epoch - 1ms/step
# Epoch 14/200
# 24/24 - 0s - loss: 0.8083 - accuracy: 0.7417 - 32ms/epoch - 1ms/step
# Epoch 15/200
# 24/24 - 0s - loss: 0.7205 - accuracy: 0.8667 - 33ms/epoch - 1ms/step
# Epoch 16/200
# 24/24 - 0s - loss: 0.6777 - accuracy: 0.8500 - 32ms/epoch - 1ms/step
# Epoch 17/200
# 24/24 - 0s - loss: 0.6402 - accuracy: 0.8500 - 34ms/epoch - 1ms/step
# Epoch 18/200
# 24/24 - 0s - loss: 0.6074 - accuracy: 0.8917 - 33ms/epoch - 1ms/step
# Epoch 19/200
# 24/24 - 0s - loss: 0.5811 - accuracy: 0.8750 - 22ms/epoch - 912us/step
# Epoch 20/200
# 24/24 - 0s - loss: 0.5563 - accuracy: 0.9167 - 19ms/epoch - 782us/step
# Epoch 21/200
# 24/24 - 0s - loss: 0.5363 - accuracy: 0.9000 - 17ms/epoch - 727us/step
# Epoch 22/200
# 24/24 - 0s - loss: 0.5213 - accuracy: 0.8667 - 18ms/epoch - 733us/step
# Epoch 23/200
# 24/24 - 0s - loss: 0.4998 - accuracy: 0.9500 - 34ms/epoch - 1ms/step
# Epoch 24/200
# 24/24 - 0s - loss: 0.4857 - accuracy: 0.9417 - 33ms/epoch - 1ms/step
# Epoch 25/200
# 24/24 - 0s - loss: 0.4759 - accuracy: 0.9000 - 16ms/epoch - 666us/step
# Epoch 26/200
# 24/24 - 0s - loss: 0.4608 - accuracy: 0.9167 - 33ms/epoch - 1ms/step
# Epoch 27/200
# 24/24 - 0s - loss: 0.4463 - accuracy: 0.9583 - 35ms/epoch - 1ms/step
# Epoch 28/200
# 24/24 - 0s - loss: 0.4368 - accuracy: 0.9333 - 33ms/epoch - 1ms/step
# Epoch 29/200
# 24/24 - 0s - loss: 0.4265 - accuracy: 0.9583 - 32ms/epoch - 1ms/step
# Epoch 30/200
# 24/24 - 0s - loss: 0.4175 - accuracy: 0.9500 - 33ms/epoch - 1ms/step
# Epoch 31/200
# 24/24 - 0s - loss: 0.4079 - accuracy: 0.9583 - 34ms/epoch - 1ms/step
# Epoch 32/200
# 24/24 - 0s - loss: 0.3992 - accuracy: 0.9583 - 25ms/epoch - 1ms/step
# Epoch 33/200
# 24/24 - 0s - loss: 0.3928 - accuracy: 0.9750 - 39ms/epoch - 2ms/step
# Epoch 34/200
# 24/24 - 0s - loss: 0.3845 - accuracy: 0.9500 - 23ms/epoch - 950us/step
# Epoch 35/200
# 24/24 - 0s - loss: 0.3756 - accuracy: 0.9417 - 35ms/epoch - 1ms/step
# Epoch 36/200
# 24/24 - 0s - loss: 0.3662 - accuracy: 0.9583 - 34ms/epoch - 1ms/step
# Epoch 37/200
# 24/24 - 0s - loss: 0.3610 - accuracy: 0.9500 - 22ms/epoch - 917us/step
# Epoch 38/200
# 24/24 - 0s - loss: 0.3557 - accuracy: 0.9500 - 33ms/epoch - 1ms/step
# Epoch 39/200
# 24/24 - 0s - loss: 0.3468 - accuracy: 0.9500 - 33ms/epoch - 1ms/step
# Epoch 40/200
# 24/24 - 0s - loss: 0.3490 - accuracy: 0.9583 - 33ms/epoch - 1ms/step
# Epoch 41/200
# 24/24 - 0s - loss: 0.3392 - accuracy: 0.9500 - 32ms/epoch - 1ms/step
# Epoch 42/200
# 24/24 - 0s - loss: 0.3265 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 43/200
# 24/24 - 0s - loss: 0.3172 - accuracy: 0.9583 - 27ms/epoch - 1ms/step
# Epoch 44/200
# 24/24 - 0s - loss: 0.3129 - accuracy: 0.9583 - 34ms/epoch - 1ms/step
# Epoch 45/200
# 24/24 - 0s - loss: 0.3090 - accuracy: 0.9500 - 33ms/epoch - 1ms/step
# Epoch 46/200
# 24/24 - 0s - loss: 0.3005 - accuracy: 0.9667 - 33ms/epoch - 1ms/step
# Epoch 47/200
# 24/24 - 0s - loss: 0.2963 - accuracy: 0.9417 - 33ms/epoch - 1ms/step
# Epoch 48/200
# 24/24 - 0s - loss: 0.2969 - accuracy: 0.9417 - 37ms/epoch - 2ms/step
# Epoch 49/200
# 24/24 - 0s - loss: 0.2896 - accuracy: 0.9500 - 22ms/epoch - 899us/step
# Epoch 50/200
# 24/24 - 0s - loss: 0.2815 - accuracy: 0.9333 - 43ms/epoch - 2ms/step
# Epoch 51/200
# 24/24 - 0s - loss: 0.2807 - accuracy: 0.9583 - 38ms/epoch - 2ms/step
# Epoch 52/200
# 24/24 - 0s - loss: 0.2632 - accuracy: 0.9667 - 33ms/epoch - 1ms/step
# Epoch 53/200
# 24/24 - 0s - loss: 0.2569 - accuracy: 0.9667 - 50ms/epoch - 2ms/step
# Epoch 54/200
# 24/24 - 0s - loss: 0.2541 - accuracy: 0.9583 - 33ms/epoch - 1ms/step
# Epoch 55/200
# 24/24 - 0s - loss: 0.2494 - accuracy: 0.9583 - 19ms/epoch - 781us/step
# Epoch 56/200
# 24/24 - 0s - loss: 0.2430 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 57/200
# 24/24 - 0s - loss: 0.2367 - accuracy: 0.9750 - 32ms/epoch - 1ms/step
# Epoch 58/200
# 24/24 - 0s - loss: 0.2306 - accuracy: 0.9667 - 33ms/epoch - 1ms/step
# Epoch 59/200
# 24/24 - 0s - loss: 0.2266 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 60/200
# 24/24 - 0s - loss: 0.2208 - accuracy: 0.9750 - 32ms/epoch - 1ms/step
# Epoch 61/200
# 24/24 - 0s - loss: 0.2171 - accuracy: 0.9750 - 30ms/epoch - 1ms/step
# Epoch 62/200
# 24/24 - 0s - loss: 0.2176 - accuracy: 0.9667 - 49ms/epoch - 2ms/step
# Epoch 63/200
# 24/24 - 0s - loss: 0.2100 - accuracy: 0.9667 - 29ms/epoch - 1ms/step
# Epoch 64/200
# 24/24 - 0s - loss: 0.2027 - accuracy: 0.9833 - 33ms/epoch - 1ms/step
# Epoch 65/200
# 24/24 - 0s - loss: 0.1991 - accuracy: 0.9833 - 32ms/epoch - 1ms/step
# Epoch 66/200
# 24/24 - 0s - loss: 0.1963 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 67/200
# 24/24 - 0s - loss: 0.1921 - accuracy: 0.9667 - 32ms/epoch - 1ms/step
# Epoch 68/200
# 24/24 - 0s - loss: 0.1937 - accuracy: 0.9583 - 27ms/epoch - 1ms/step
# Epoch 69/200
# 24/24 - 0s - loss: 0.1839 - accuracy: 0.9667 - 37ms/epoch - 2ms/step
# Epoch 70/200
# 24/24 - 0s - loss: 0.1788 - accuracy: 0.9667 - 23ms/epoch - 976us/step
# Epoch 71/200
# 24/24 - 0s - loss: 0.1818 - accuracy: 0.9500 - 41ms/epoch - 2ms/step
# Epoch 72/200
# 24/24 - 0s - loss: 0.1837 - accuracy: 0.9500 - 34ms/epoch - 1ms/step
# Epoch 73/200
# 24/24 - 0s - loss: 0.1720 - accuracy: 0.9750 - 22ms/epoch - 902us/step
# Epoch 74/200
# 24/24 - 0s - loss: 0.1684 - accuracy: 0.9750 - 42ms/epoch - 2ms/step
# Epoch 75/200
# 24/24 - 0s - loss: 0.1657 - accuracy: 0.9750 - 23ms/epoch - 975us/step
# Epoch 76/200
# 24/24 - 0s - loss: 0.1632 - accuracy: 0.9583 - 42ms/epoch - 2ms/step
# Epoch 77/200
# 24/24 - 0s - loss: 0.1594 - accuracy: 0.9750 - 22ms/epoch - 932us/step
# Epoch 78/200
# 24/24 - 0s - loss: 0.1607 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 79/200
# 24/24 - 0s - loss: 0.1540 - accuracy: 0.9833 - 33ms/epoch - 1ms/step
# Epoch 80/200
# 24/24 - 0s - loss: 0.1522 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 81/200
# 24/24 - 0s - loss: 0.1496 - accuracy: 0.9750 - 34ms/epoch - 1ms/step
# Epoch 82/200
# 24/24 - 0s - loss: 0.1486 - accuracy: 0.9667 - 32ms/epoch - 1ms/step
# Epoch 83/200
# 24/24 - 0s - loss: 0.1410 - accuracy: 0.9667 - 32ms/epoch - 1ms/step
# Epoch 84/200
# 24/24 - 0s - loss: 0.1411 - accuracy: 0.9750 - 34ms/epoch - 1ms/step
# Epoch 85/200
# 24/24 - 0s - loss: 0.1381 - accuracy: 0.9833 - 34ms/epoch - 1ms/step
# Epoch 86/200
# 24/24 - 0s - loss: 0.1372 - accuracy: 0.9667 - 30ms/epoch - 1ms/step
# Epoch 87/200
# 24/24 - 0s - loss: 0.1340 - accuracy: 0.9750 - 29ms/epoch - 1ms/step
# Epoch 88/200
# 24/24 - 0s - loss: 0.1334 - accuracy: 0.9667 - 38ms/epoch - 2ms/step
# Epoch 89/200
# 24/24 - 0s - loss: 0.1322 - accuracy: 0.9750 - 35ms/epoch - 1ms/step
# Epoch 90/200
# 24/24 - 0s - loss: 0.1383 - accuracy: 0.9667 - 32ms/epoch - 1ms/step
# Epoch 91/200
# 24/24 - 0s - loss: 0.1273 - accuracy: 0.9833 - 33ms/epoch - 1ms/step
# Epoch 92/200
# 24/24 - 0s - loss: 0.1263 - accuracy: 0.9667 - 34ms/epoch - 1ms/step
# Epoch 93/200
# 24/24 - 0s - loss: 0.1226 - accuracy: 0.9750 - 24ms/epoch - 979us/step
# Epoch 94/200
# 24/24 - 0s - loss: 0.1200 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 95/200
# 24/24 - 0s - loss: 0.1200 - accuracy: 0.9750 - 23ms/epoch - 962us/step
# Epoch 96/200
# 24/24 - 0s - loss: 0.1179 - accuracy: 0.9750 - 22ms/epoch - 910us/step
# Epoch 97/200
# 24/24 - 0s - loss: 0.1176 - accuracy: 0.9667 - 33ms/epoch - 1ms/step
# Epoch 98/200
# 24/24 - 0s - loss: 0.1138 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 99/200
# 24/24 - 0s - loss: 0.1126 - accuracy: 0.9750 - 29ms/epoch - 1ms/step
# Epoch 100/200
# 24/24 - 0s - loss: 0.1169 - accuracy: 0.9500 - 33ms/epoch - 1ms/step
# Epoch 101/200
# 24/24 - 0s - loss: 0.1098 - accuracy: 0.9750 - 34ms/epoch - 1ms/step
# Epoch 102/200
# 24/24 - 0s - loss: 0.1105 - accuracy: 0.9583 - 17ms/epoch - 707us/step
# Epoch 103/200
# 24/24 - 0s - loss: 0.1073 - accuracy: 0.9750 - 17ms/epoch - 711us/step
# Epoch 104/200
# 24/24 - 0s - loss: 0.1062 - accuracy: 0.9750 - 18ms/epoch - 738us/step
# Epoch 105/200
# 24/24 - 0s - loss: 0.1086 - accuracy: 0.9750 - 19ms/epoch - 773us/step
# Epoch 106/200
# 24/24 - 0s - loss: 0.1080 - accuracy: 0.9750 - 20ms/epoch - 818us/step
# Epoch 107/200
# 24/24 - 0s - loss: 0.1057 - accuracy: 0.9583 - 34ms/epoch - 1ms/step
# Epoch 108/200
# 24/24 - 0s - loss: 0.1166 - accuracy: 0.9667 - 19ms/epoch - 798us/step
# Epoch 109/200
# 24/24 - 0s - loss: 0.1070 - accuracy: 0.9583 - 18ms/epoch - 764us/step
# Epoch 110/200
# 24/24 - 0s - loss: 0.1000 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 111/200
# 24/24 - 0s - loss: 0.0985 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 112/200
# 24/24 - 0s - loss: 0.0999 - accuracy: 0.9750 - 38ms/epoch - 2ms/step
# Epoch 113/200
# 24/24 - 0s - loss: 0.0969 - accuracy: 0.9917 - 31ms/epoch - 1ms/step
# Epoch 114/200
# 24/24 - 0s - loss: 0.0994 - accuracy: 0.9750 - 28ms/epoch - 1ms/step
# Epoch 115/200
# 24/24 - 0s - loss: 0.1048 - accuracy: 0.9750 - 34ms/epoch - 1ms/step
# Epoch 116/200
# 24/24 - 0s - loss: 0.0933 - accuracy: 0.9750 - 41ms/epoch - 2ms/step
# Epoch 117/200
# 24/24 - 0s - loss: 0.1069 - accuracy: 0.9500 - 29ms/epoch - 1ms/step
# Epoch 118/200
# 24/24 - 0s - loss: 0.0982 - accuracy: 0.9667 - 33ms/epoch - 1ms/step
# Epoch 119/200
# 24/24 - 0s - loss: 0.0964 - accuracy: 0.9667 - 32ms/epoch - 1ms/step
# Epoch 120/200
# 24/24 - 0s - loss: 0.0897 - accuracy: 0.9917 - 21ms/epoch - 865us/step
# Epoch 121/200
# 24/24 - 0s - loss: 0.0964 - accuracy: 0.9667 - 35ms/epoch - 1ms/step
# Epoch 122/200
# 24/24 - 0s - loss: 0.0890 - accuracy: 0.9833 - 35ms/epoch - 1ms/step
# Epoch 123/200
# 24/24 - 0s - loss: 0.0925 - accuracy: 0.9667 - 21ms/epoch - 858us/step
# Epoch 124/200
# 24/24 - 0s - loss: 0.0917 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 125/200
# 24/24 - 0s - loss: 0.0872 - accuracy: 0.9750 - 32ms/epoch - 1ms/step
# Epoch 126/200
# 24/24 - 0s - loss: 0.0913 - accuracy: 0.9750 - 32ms/epoch - 1ms/step
# Epoch 127/200
# 24/24 - 0s - loss: 0.0884 - accuracy: 0.9833 - 32ms/epoch - 1ms/step
# Epoch 128/200
# 24/24 - 0s - loss: 0.0996 - accuracy: 0.9583 - 30ms/epoch - 1ms/step
# Epoch 129/200
# 24/24 - 0s - loss: 0.0898 - accuracy: 0.9667 - 33ms/epoch - 1ms/step
# Epoch 130/200
# 24/24 - 0s - loss: 0.0904 - accuracy: 0.9667 - 39ms/epoch - 2ms/step
# Epoch 131/200
# 24/24 - 0s - loss: 0.0867 - accuracy: 0.9750 - 32ms/epoch - 1ms/step
# Epoch 132/200
# 24/24 - 0s - loss: 0.0863 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 133/200
# 24/24 - 0s - loss: 0.0822 - accuracy: 0.9750 - 25ms/epoch - 1ms/step
# Epoch 134/200
# 24/24 - 0s - loss: 0.0855 - accuracy: 0.9750 - 38ms/epoch - 2ms/step
# Epoch 135/200
# 24/24 - 0s - loss: 0.0888 - accuracy: 0.9833 - 24ms/epoch - 990us/step
# Epoch 136/200
# 24/24 - 0s - loss: 0.0850 - accuracy: 0.9833 - 21ms/epoch - 864us/step
# Epoch 137/200
# 24/24 - 0s - loss: 0.0832 - accuracy: 0.9750 - 34ms/epoch - 1ms/step
# Epoch 138/200
# 24/24 - 0s - loss: 0.0803 - accuracy: 0.9833 - 32ms/epoch - 1ms/step
# Epoch 139/200
# 24/24 - 0s - loss: 0.0796 - accuracy: 0.9750 - 32ms/epoch - 1ms/step
# Epoch 140/200
# 24/24 - 0s - loss: 0.0819 - accuracy: 0.9750 - 32ms/epoch - 1ms/step
# Epoch 141/200
# 24/24 - 0s - loss: 0.0801 - accuracy: 0.9833 - 31ms/epoch - 1ms/step
# Epoch 142/200
# 24/24 - 0s - loss: 0.0790 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 143/200
# 24/24 - 0s - loss: 0.0818 - accuracy: 0.9667 - 40ms/epoch - 2ms/step
# Epoch 144/200
# 24/24 - 0s - loss: 0.0794 - accuracy: 0.9750 - 32ms/epoch - 1ms/step
# Epoch 145/200
# 24/24 - 0s - loss: 0.0813 - accuracy: 0.9667 - 23ms/epoch - 938us/step
# Epoch 146/200
# 24/24 - 0s - loss: 0.0839 - accuracy: 0.9750 - 41ms/epoch - 2ms/step
# Epoch 147/200
# 24/24 - 0s - loss: 0.0880 - accuracy: 0.9833 - 32ms/epoch - 1ms/step
# Epoch 148/200
# 24/24 - 0s - loss: 0.0761 - accuracy: 0.9833 - 23ms/epoch - 975us/step
# Epoch 149/200
# 24/24 - 0s - loss: 0.0757 - accuracy: 0.9750 - 16ms/epoch - 668us/step
# Epoch 150/200
# 24/24 - 0s - loss: 0.0770 - accuracy: 0.9750 - 21ms/epoch - 862us/step
# Epoch 151/200
# 24/24 - 0s - loss: 0.0846 - accuracy: 0.9833 - 45ms/epoch - 2ms/step
# Epoch 152/200
# 24/24 - 0s - loss: 0.0748 - accuracy: 0.9833 - 33ms/epoch - 1ms/step
# Epoch 153/200
# 24/24 - 0s - loss: 0.0750 - accuracy: 0.9750 - 32ms/epoch - 1ms/step
# Epoch 154/200
# 24/24 - 0s - loss: 0.0794 - accuracy: 0.9917 - 31ms/epoch - 1ms/step
# Epoch 155/200
# 24/24 - 0s - loss: 0.0735 - accuracy: 0.9667 - 33ms/epoch - 1ms/step
# Epoch 156/200
# 24/24 - 0s - loss: 0.0748 - accuracy: 0.9750 - 39ms/epoch - 2ms/step
# Epoch 157/200
# 24/24 - 0s - loss: 0.0761 - accuracy: 0.9833 - 50ms/epoch - 2ms/step
# Epoch 158/200
# 24/24 - 0s - loss: 0.0726 - accuracy: 0.9750 - 22ms/epoch - 900us/step
# Epoch 159/200
# 24/24 - 0s - loss: 0.0771 - accuracy: 0.9750 - 45ms/epoch - 2ms/step
# Epoch 160/200
# 24/24 - 0s - loss: 0.0824 - accuracy: 0.9750 - 20ms/epoch - 820us/step
# Epoch 161/200
# 24/24 - 0s - loss: 0.0753 - accuracy: 0.9750 - 38ms/epoch - 2ms/step
# Epoch 162/200
# 24/24 - 0s - loss: 0.0738 - accuracy: 0.9833 - 34ms/epoch - 1ms/step
# Epoch 163/200
# 24/24 - 0s - loss: 0.0723 - accuracy: 0.9750 - 29ms/epoch - 1ms/step
# Epoch 164/200
# 24/24 - 0s - loss: 0.0718 - accuracy: 0.9833 - 33ms/epoch - 1ms/step
# Epoch 165/200
# 24/24 - 0s - loss: 0.0757 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 166/200
# 24/24 - 0s - loss: 0.0718 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 167/200
# 24/24 - 0s - loss: 0.0723 - accuracy: 0.9917 - 29ms/epoch - 1ms/step
# Epoch 168/200
# 24/24 - 0s - loss: 0.0756 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 169/200
# 24/24 - 0s - loss: 0.0722 - accuracy: 0.9750 - 37ms/epoch - 2ms/step
# Epoch 170/200
# 24/24 - 0s - loss: 0.0698 - accuracy: 0.9833 - 32ms/epoch - 1ms/step
# Epoch 171/200
# 24/24 - 0s - loss: 0.0736 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 172/200
# 24/24 - 0s - loss: 0.0835 - accuracy: 0.9667 - 33ms/epoch - 1ms/step
# Epoch 173/200
# 24/24 - 0s - loss: 0.0784 - accuracy: 0.9583 - 29ms/epoch - 1ms/step
# Epoch 174/200
# 24/24 - 0s - loss: 0.0764 - accuracy: 0.9583 - 33ms/epoch - 1ms/step
# Epoch 175/200
# 24/24 - 0s - loss: 0.0699 - accuracy: 0.9833 - 42ms/epoch - 2ms/step
# Epoch 176/200
# 24/24 - 0s - loss: 0.0822 - accuracy: 0.9583 - 22ms/epoch - 899us/step
# Epoch 177/200
# 24/24 - 0s - loss: 0.0728 - accuracy: 0.9750 - 23ms/epoch - 977us/step
# Epoch 178/200
# 24/24 - 0s - loss: 0.0715 - accuracy: 0.9750 - 34ms/epoch - 1ms/step
# Epoch 179/200
# 24/24 - 0s - loss: 0.0677 - accuracy: 0.9750 - 34ms/epoch - 1ms/step
# Epoch 180/200
# 24/24 - 0s - loss: 0.0702 - accuracy: 0.9750 - 28ms/epoch - 1ms/step
# Epoch 181/200
# 24/24 - 0s - loss: 0.0688 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 182/200
# 24/24 - 0s - loss: 0.0717 - accuracy: 0.9750 - 38ms/epoch - 2ms/step
# Epoch 183/200
# 24/24 - 0s - loss: 0.0723 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 184/200
# 24/24 - 0s - loss: 0.0710 - accuracy: 0.9750 - 34ms/epoch - 1ms/step
# Epoch 185/200
# 24/24 - 0s - loss: 0.0660 - accuracy: 0.9833 - 22ms/epoch - 906us/step
# Epoch 186/200
# 24/24 - 0s - loss: 0.0660 - accuracy: 0.9750 - 42ms/epoch - 2ms/step
# Epoch 187/200
# 24/24 - 0s - loss: 0.0673 - accuracy: 0.9833 - 22ms/epoch - 919us/step
# Epoch 188/200
# 24/24 - 0s - loss: 0.0717 - accuracy: 0.9917 - 33ms/epoch - 1ms/step
# Epoch 189/200
# 24/24 - 0s - loss: 0.0621 - accuracy: 0.9833 - 23ms/epoch - 965us/step
# Epoch 190/200
# 24/24 - 0s - loss: 0.0709 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 191/200
# 24/24 - 0s - loss: 0.0681 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 192/200
# 24/24 - 0s - loss: 0.0703 - accuracy: 0.9583 - 33ms/epoch - 1ms/step
# Epoch 193/200
# 24/24 - 0s - loss: 0.0674 - accuracy: 0.9833 - 34ms/epoch - 1ms/step
# Epoch 194/200
# 24/24 - 0s - loss: 0.0642 - accuracy: 0.9750 - 27ms/epoch - 1ms/step
# Epoch 195/200
# 24/24 - 0s - loss: 0.0636 - accuracy: 0.9833 - 38ms/epoch - 2ms/step
# Epoch 196/200
# 24/24 - 0s - loss: 0.0851 - accuracy: 0.9500 - 23ms/epoch - 943us/step
# Epoch 197/200
# 24/24 - 0s - loss: 0.0614 - accuracy: 0.9917 - 34ms/epoch - 1ms/step
# Epoch 198/200
# 24/24 - 0s - loss: 0.0681 - accuracy: 0.9750 - 34ms/epoch - 1ms/step
# Epoch 199/200
# 24/24 - 0s - loss: 0.0647 - accuracy: 0.9750 - 33ms/epoch - 1ms/step
# Epoch 200/200
# 24/24 - 0s - loss: 0.0642 - accuracy: 0.9750 - 29ms/epoch - 1ms/step

# %%
# Test on unseen data
results = model.evaluate(test_x, test_y)
print('Final test set accuracy:',results[1])
# Out:
# 1/1 [==============================] - 0s 160ms/step - loss: 0.0675 - accuracy: 0.9667
# Final test set accuracy: 0.9666666388511658
